# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from viz import *
# %matplotlib inline

# handling Data
raw_df = pd.read_csv(r"F:\desktop backup august12021\21WORK\automate_boring_stuff\2023\RELIANCE_WEBSITE_RANK_SEO\sparkbark\ranked_files\part-00000-479a3425-7873-4dea-9f1f-a2109d794fb8-c000.csv",names=['id','file_id','domain','rank','category','keyword',"url"])
# category Based Data
Amazon_Ac_category_df = raw_df[raw_df['category']=='Amazon_Ac_category']
Amazon_Laptop_category_df = raw_df[raw_df['category']=='Amazon_Laptop_category']
Camera_category_df = raw_df[raw_df['category']=='Camera_category']
Home_entertainment_category_df = raw_df[raw_df['category']=='Home_entertainment_category']
Smartphone_category_df = raw_df[raw_df['category']=='Smartphone_category']

# %% [markdown]
# ### NOTE : this eda is strictly as per the 2649 keywords used to find ranking Dated 23-02-2023

# %% [markdown]
# # ANALYSIS BASED ON ALL KEYWORDS

# %% [markdown]
# ### EDA of Keywords

# %%
key_dist(raw_df)

# %%
Word_cloud(raw_df.keyword)

# %% [markdown]
# ---------

# %% [markdown]
# # Overview

# %%
plot_my_rank(raw_df,"Complete Distribution of Rankings")

# %% [markdown]
# ---

# %% [markdown]
# # categorical distribution

# %%
plot_my_rank(Amazon_Ac_category_df,"Amazon Ac Category")

# %%
plot_my_rank(Amazon_Laptop_category_df,"Amazon Laptop Category")

# %%
plot_my_rank(Camera_category_df,"Camera Category")

# %%
plot_my_rank(Home_entertainment_category_df,"Home_entertainment_category")

# %%
plot_my_rank(Smartphone_category_df,"Smartphone_category")
